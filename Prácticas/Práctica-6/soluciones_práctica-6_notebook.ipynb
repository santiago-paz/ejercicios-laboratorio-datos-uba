# %% [markdown]
# # Práctica 6
# ## Operaciones con DataFrames y transformaciones de datos.

# %% [markdown]
# ### **Carga de librerías y del dataset penguins**

# %%
import seaborn as sns
import seaborn.objects as so
import pandas as pd
import numpy as np

penguins = sns.load_dataset('penguins')
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %% [markdown]
# ### **Ejercicio 1**

# %%
# Creamos un subconjunto de datos que contengan solo los pinguinos de la isla Biscoe, y que tengan un pico mayor de 48mm

penguins_biscoe = (penguins[
    (penguins['island'] == 'Biscoe') &
    (penguins['bill_length_mm'] > 48)])
penguins_biscoe.head()
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 221  Gentoo  Biscoe            50.0           16.3              230.0
# 222  Gentoo  Biscoe            48.7           14.1              210.0
# 223  Gentoo  Biscoe            50.0           15.2              218.0
# 231  Gentoo  Biscoe            49.0           16.1              216.0
# 233  Gentoo  Biscoe            48.4           14.6              213.0
#
#      body_mass_g     sex
# 221       5700.0    Male
# 222       4450.0  Female
# 223       5700.0    Male
# 231       5550.0    Male
# 233       5850.0    Male

# %% [markdown]
# ### **Ejercicio 2**

# %%
# Creamos otro dataset de pinguinos macho Adelie que no sean de la isla de Biscoe

penguins_adelie = penguins[(penguins['species'] == 'Adelie') & (penguins['island'] != 'Biscoe')]
penguins_adelie.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %% [markdown]
# ### **Ejercicio 3**

# %%
# Del dataset penguins nos quedamos con todas las variables excepto year, sex y body_mass_g

# Preguntar: No existe la variable 'year' en el dataset penguins
#penguins_subset = penguins.drop(columns=['year', 'sex', 'body_mass_g'])

penguins_subset = penguins.drop(columns=['sex', 'body_mass_g'])
penguins_subset.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0

# %% [markdown]
# ### **Ejercicio 4**

# %%
# Ejercicio 4 (a)
# Eliminamos las filas con datos faltantes en el dataset penguins

penguins_clean = penguins.dropna()
penguins_clean.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 4       3450.0  Female
# 5       3650.0    Male

# %% [markdown]
# #### Como vemos 👆, los indices siguientes no son consecutivos, ya que hemos eliminado filas

# %%
# Ejercicio 4 (b)
# Restablecemos el índice del dataset penguins_clean

penguins_clean = penguins_clean.reset_index(drop=True)
penguins_clean.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen            36.7           19.3              193.0
# 4  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3       3450.0  Female
# 4       3650.0    Male

# %%
# Ejercicio 4 (c)
# Hacemos lo mismo encadenando los métodos dropna() y reset_index()

penguins_clean = penguins.dropna().reset_index(drop=True)
penguins_clean.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen            36.7           19.3              193.0
# 4  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3       3450.0  Female
# 4       3650.0    Male

# %% [markdown]
# ### **Ejercicio 5**

# %%
# Ejercicio 5 (a)
# Renombramos la columna "species" a "especies", en el dataset penguins

penguins_renombrada = penguins.rename(columns={'species': 'especies'})
penguins_renombrada.head()
# Out:
#   especies     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0   Adelie  Torgersen            39.1           18.7              181.0
# 1   Adelie  Torgersen            39.5           17.4              186.0
# 2   Adelie  Torgersen            40.3           18.0              195.0
# 3   Adelie  Torgersen             NaN            NaN                NaN
# 4   Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
# Ejercicio 5 (b)
# Renombramos la variable flipper_length_mm a aleta_mm y la variable body_mass_g a peso_g en el dataset penguins_renombrada

penguins_renombrada = penguins_renombrada.rename(
    columns={'flipper_length_mm': 'aleta_mm', 'body_mass_g': 'peso_g'})
penguins_renombrada.head()
# Out:
#   especies     island  bill_length_mm  bill_depth_mm  aleta_mm  peso_g     sex
# 0   Adelie  Torgersen            39.1           18.7     181.0  3750.0    Male
# 1   Adelie  Torgersen            39.5           17.4     186.0  3800.0  Female
# 2   Adelie  Torgersen            40.3           18.0     195.0  3250.0  Female
# 3   Adelie  Torgersen             NaN            NaN       NaN     NaN     NaN
# 4   Adelie  Torgersen            36.7           19.3     193.0  3450.0  Female

# %%
# Ejercicio 5 (c)
# Renombramos el indice 0 a "cero" en el dataset penguins_renombrada

penguins_renombrada = penguins_renombrada.rename(index={0: 'cero'})
penguins_renombrada.head()
# Out:
#      especies     island  bill_length_mm  bill_depth_mm  aleta_mm  peso_g  \
# cero   Adelie  Torgersen            39.1           18.7     181.0  3750.0
# 1      Adelie  Torgersen            39.5           17.4     186.0  3800.0
# 2      Adelie  Torgersen            40.3           18.0     195.0  3250.0
# 3      Adelie  Torgersen             NaN            NaN       NaN     NaN
# 4      Adelie  Torgersen            36.7           19.3     193.0  3450.0
#
#          sex
# cero    Male
# 1     Female
# 2     Female
# 3        NaN
# 4     Female

# %%
# Ejercicio 5 (d)
# Pasamos todos los nombres de las columnas a mayúsculas en el dataset penguins_renombrada

penguins_renombrada.columns = penguins_renombrada.columns.str.upper()
penguins_renombrada.head()
# Out:
#      ESPECIES     ISLAND  BILL_LENGTH_MM  BILL_DEPTH_MM  ALETA_MM  PESO_G  \
# cero   Adelie  Torgersen            39.1           18.7     181.0  3750.0
# 1      Adelie  Torgersen            39.5           17.4     186.0  3800.0
# 2      Adelie  Torgersen            40.3           18.0     195.0  3250.0
# 3      Adelie  Torgersen             NaN            NaN       NaN     NaN
# 4      Adelie  Torgersen            36.7           19.3     193.0  3450.0
#
#          SEX
# cero    Male
# 1     Female
# 2     Female
# 3        NaN
# 4     Female

# %%
# Ejercicio 5 (e)

penguins = penguins.rename(index = np.sqrt)
penguins.head()
# Out:
#          species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0.000000  Adelie  Torgersen            39.1           18.7              181.0
# 1.000000  Adelie  Torgersen            39.5           17.4              186.0
# 1.414214  Adelie  Torgersen            40.3           18.0              195.0
# 1.732051  Adelie  Torgersen             NaN            NaN                NaN
# 2.000000  Adelie  Torgersen            36.7           19.3              193.0
#
#           body_mass_g     sex
# 0.000000       3750.0    Male
# 1.000000       3800.0  Female
# 1.414214       3250.0  Female
# 1.732051          NaN     NaN
# 2.000000       3450.0  Female

# %% [markdown]
# #### Como vemos 👆, aplica a cada índice de la fila su raíz cuadrada

# %%
# Ejercicio 5 (f)
# Sumamos 1 a todos los índices del dataset penguins

def suma_uno(x):
    return x + 1

penguins = penguins.rename(index = suma_uno)
penguins.head()
# Out:
#          species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 1.000000  Adelie  Torgersen            39.1           18.7              181.0
# 2.000000  Adelie  Torgersen            39.5           17.4              186.0
# 2.414214  Adelie  Torgersen            40.3           18.0              195.0
# 2.732051  Adelie  Torgersen             NaN            NaN                NaN
# 3.000000  Adelie  Torgersen            36.7           19.3              193.0
#
#           body_mass_g     sex
# 1.000000       3750.0    Male
# 2.000000       3800.0  Female
# 2.414214       3250.0  Female
# 2.732051          NaN     NaN
# 3.000000       3450.0  Female

# %%
# Ejercicio 5 (g)
# Utilizamos una función lambda para hacer lo mismo que en el ejercicio anterior

penguins = penguins.rename(index = lambda x: x + 1)
penguins.head()
# Out:
#          species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 2.000000  Adelie  Torgersen            39.1           18.7              181.0
# 3.000000  Adelie  Torgersen            39.5           17.4              186.0
# 3.414214  Adelie  Torgersen            40.3           18.0              195.0
# 3.732051  Adelie  Torgersen             NaN            NaN                NaN
# 4.000000  Adelie  Torgersen            36.7           19.3              193.0
#
#           body_mass_g     sex
# 2.000000       3750.0    Male
# 3.000000       3800.0  Female
# 3.414214       3250.0  Female
# 3.732051          NaN     NaN
# 4.000000       3450.0  Female

# %%
# Ejercicio 5 (h)
# Utilizamos una función lambda para pasar todos los nombres de las columnas a mayúsculas en el dataset penguins

penguins = penguins.rename(columns = lambda x: x.upper())
penguins.head()
# Out:
#          SPECIES     ISLAND  BILL_LENGTH_MM  BILL_DEPTH_MM  FLIPPER_LENGTH_MM  \
# 2.000000  Adelie  Torgersen            39.1           18.7              181.0
# 3.000000  Adelie  Torgersen            39.5           17.4              186.0
# 3.414214  Adelie  Torgersen            40.3           18.0              195.0
# 3.732051  Adelie  Torgersen             NaN            NaN                NaN
# 4.000000  Adelie  Torgersen            36.7           19.3              193.0
#
#           BODY_MASS_G     SEX
# 2.000000       3750.0    Male
# 3.000000       3800.0  Female
# 3.414214       3250.0  Female
# 3.732051          NaN     NaN
# 4.000000       3450.0  Female

# %% [markdown]
# ### **Ejercicio 6**

# %%
# Ejercicio 6 (a)

saludos = [saludo + '!' for saludo in ['hola', 'chau']]
saludos
# Out:
# ['hola!', 'chau!']

# %%
# Ejercicio 6 (b)

# Convertimos todos los nombres de variables a mayúsculas en el dataset penguins utilizando una lista de comprensión
# Cargamos nuevamente el dataset penguins para resetear los cambios realizados en los ejercicios anteriores

penguins = sns.load_dataset('penguins')
penguins.columns = [column.upper() for column in penguins.columns]
penguins.head()
# Out:
#   SPECIES     ISLAND  BILL_LENGTH_MM  BILL_DEPTH_MM  FLIPPER_LENGTH_MM  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    BODY_MASS_G     SEX
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %% [markdown]
# ### **Ejercicio 7**

# %%
# Cargamos nuevamente el dataset penguins para resetear los cambios realizados en el ejercicio anterior

penguins = sns.load_dataset('penguins')

# Convertimos a mayúsculas los nombres de columnas que comienzan con "bill" en el dataset penguins solamente

penguins.columns = [column.upper() if column.startswith('bill') else column for column in penguins.columns]
penguins.head()
# Out:
#   species     island  BILL_LENGTH_MM  BILL_DEPTH_MM  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %% [markdown]
# ### **Ejercicio 8**

# %%
# Creamos una nueva columna en el dataset que contenga "chico" si body_mass_g es menor a 4000, y "grande" en caso contrario

penguins['tamaño'] = np.where(penguins['body_mass_g'] < 4000, 'chico', 'grande')
penguins = penguins.dropna()
penguins.head(10)
# Out:
#    species     island  BILL_LENGTH_MM  BILL_DEPTH_MM  flipper_length_mm  \
# 0   Adelie  Torgersen            39.1           18.7              181.0
# 1   Adelie  Torgersen            39.5           17.4              186.0
# 2   Adelie  Torgersen            40.3           18.0              195.0
# 4   Adelie  Torgersen            36.7           19.3              193.0
# 5   Adelie  Torgersen            39.3           20.6              190.0
# 6   Adelie  Torgersen            38.9           17.8              181.0
# 7   Adelie  Torgersen            39.2           19.6              195.0
# 12  Adelie  Torgersen            41.1           17.6              182.0
# 13  Adelie  Torgersen            38.6           21.2              191.0
# 14  Adelie  Torgersen            34.6           21.1              198.0
#
#     body_mass_g     sex  tamaño
# 0        3750.0    Male   chico
# 1        3800.0  Female   chico
# 2        3250.0  Female   chico
# 4        3450.0  Female   chico
# ...

# %% [markdown]
# ### **Ejercicio 9**

# %%
# Cargamos nuevamente el dataset penguins para resetear los cambios realizados en el ejercicio anterior

penguins = sns.load_dataset('penguins')

# Creamos un subconjunto de datos solo con las observaciones de pinguinos con aletas mayores a 200mm

penguins_mayores_200 = penguins[penguins['flipper_length_mm'] > 200]

# Nos quedamos solamente con las columnas que terminan con "_mm" en el dataset penguins

penguins_mayores_200 = penguins_mayores_200.loc[:, penguins_mayores_200.columns.str.endswith('_mm')]

# Reseteamos el índice del dataset penguins_mayores_200

penguins_mayores_200 = penguins_mayores_200.reset_index(drop=True)
penguins_mayores_200.head()
# Out:
#    bill_length_mm  bill_depth_mm  flipper_length_mm
# 0            35.7           18.0              202.0
# 1            41.1           18.1              205.0
# 2            40.8           18.9              208.0
# 3            41.0           20.0              203.0
# 4            41.4           18.5              202.0

# %% [markdown]
# ### **Ejercicio 10**

# %%
# Creamos un nuevo dataframe a partir de penguins que tenga solo las observaciones de la isla "Dream"

penguins_dream = penguins[penguins['island'] == 'Dream']

# Nos quedamos con las columnas "species" y todas las que comienzan con "bill" en el dataset penguins_dream

penguins_dream = penguins_dream.loc[:, ['species'] + list(penguins_dream.columns[penguins_dream.columns.str.startswith('bill')])]

penguins_dream.head()
# Out:
#    species  bill_length_mm  bill_depth_mm
# 30  Adelie            39.5           16.7
# 31  Adelie            37.2           18.1
# 32  Adelie            39.5           17.8
# 33  Adelie            40.9           18.9
# 34  Adelie            36.4           17.0

# %% [markdown]
# ### **Ejercicio 11**

# %%
# Ejercicio 11 (a)
# Creamos una nueva columna "peso_en_kg" en el dataset penguins que contenga el peso en kilogramos

penguins['peso_en_kg'] = penguins['body_mass_g'] / 1000
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex  peso_en_kg
# 0       3750.0    Male        3.75
# 1       3800.0  Female        3.80
# 2       3250.0  Female        3.25
# 3          NaN     NaN         NaN
# 4       3450.0  Female        3.45

# %%
# Ejercicio 11 (b)
# Convertimos la columna island a minúsculas en el dataset penguins

penguins.island = penguins.island.str.lower()
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  torgersen            39.1           18.7              181.0
# 1  Adelie  torgersen            39.5           17.4              186.0
# 2  Adelie  torgersen            40.3           18.0              195.0
# 3  Adelie  torgersen             NaN            NaN                NaN
# 4  Adelie  torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex  peso_en_kg
# 0       3750.0    Male        3.75
# 1       3800.0  Female        3.80
# 2       3250.0  Female        3.25
# 3          NaN     NaN         NaN
# 4       3450.0  Female        3.45

# %% [markdown]
# ### **Ejercicio 12**

# %%
# Cargamos nuevamente el dataset penguins para resetear los cambios realizados en el ejercicio anterior

penguins = sns.load_dataset('penguins')

# Agregamos una nueva columna con la mediana de la masa corporal de cada especie de pinguino en el dataset penguins, usando group_by

penguins['mediana_peso'] = penguins.groupby('species')['body_mass_g'].transform('median')

# Obtenemos filas al azar del dataset penguins

penguins.sample(10)
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 24      Adelie     Biscoe            38.8           17.2              180.0
# 245     Gentoo     Biscoe            46.1           15.1              215.0
# 133     Adelie      Dream            37.5           18.5              199.0
# 203  Chinstrap      Dream            51.4           19.0              201.0
# 226     Gentoo     Biscoe            45.4           14.6              211.0
# 56      Adelie     Biscoe            39.0           17.5              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 306     Gentoo     Biscoe            43.4           14.4              218.0
# 43      Adelie      Dream            44.1           19.7              196.0
# 266     Gentoo     Biscoe            45.5           13.9              210.0
#
#      body_mass_g     sex  mediana_peso
# 24        3800.0    Male        3700.0
# 245       5100.0    Male        5000.0
# ...

# %% [markdown]
# ### **Ejercicio 13**

# %%
# Cargamos nuevamente el dataset penguins para resetear los cambios realizados en el ejercicio anterior

penguins = sns.load_dataset('penguins')

# Ejercicio 13 (a)
# Excluimos a los pinguinos observados en la isla "Biscoe"

new_penguins = penguins[penguins['island'] != 'Biscoe']

# Ejercicio 13 (b)
# Nos quedamos con las columnas que estén entre "species" y "body_mass_g" en el dataset "new_penguins"

new_penguins = new_penguins.loc[:, 'species':'body_mass_g']

# Ejercicio 13 (c)
# Renombramos la columna "species" "especie_pinguino"

new_penguins = new_penguins.rename(columns={'species': 'especie_pinguino'})

# Ejercicio 13 (d)
# Agrupamos los datos por "especie_pinguino"

new_penguins_grouped = new_penguins.groupby('especie_pinguino')

# Ejercicio 13 (e)
# ???

# %% [markdown]
# ### **Ejercicio 14**

# %%
# Cargamos el dataset macro_full_columns.csv, usando la columna Anio como índice
macroFull = pd.read_csv('../../Datos/macro_full_columns.csv', index_col='Anio')

# Ejercicio 14 (a)
macroFull.head()
# Out:
#       Unnamed: 0  FBKF.Construcciones.Priv_Publ  \
# Anio
# 1950           1                    20353627362
# 1951           2                    21739314091
# 1952           3                    19685428171
# 1953           4                    20237375978
# 1954           5                    19372130307
#
#       FBKF.Equi_Dur_Prod.Mat_Transp.Nac  FBKF.Equi_Dur_Prod.Mat_Transp.Import  \
# Anio
# 1950                       6.685869e+08                          5.844002e+08
# 1951                       8.427402e+08                          2.532758e+09
# 1952                       1.119084e+09                          1.484422e+09
# 1953                       1.207891e+09                          1.459989e+09
# 1954                       1.173452e+09                          8.059002e+08
#
#       FBKF.Equi_Dur_Prod.Maqui_YEqui.Nac  \
# Anio
# 1950                          3119383475
# 1951                          3562534310
# 1952                          3440750327
# ...

# %%
# Eliminamos la columna "Unnamed: 0" del dataset macroFull, y listamos el nombre de todas las columnas

macroFull = macroFull.drop(columns='Unnamed: 0')
macroFull.columns
# Out:
# Index(['FBKF.Construcciones.Priv_Publ', 'FBKF.Equi_Dur_Prod.Mat_Transp.Nac',
#        'FBKF.Equi_Dur_Prod.Mat_Transp.Import',
#        'FBKF.Equi_Dur_Prod.Maqui_YEqui.Nac',
#        'FBKF.Equi_Dur_Prod.Maqui_YEqui.Import', 'Consumo.Hogares',
#        'Consumo.Gobierno', 'Exportaciones', 'Importaciones', 'GIB', 'FKBF',
#        'EXPO_TOT_2004', 'EXPO_AGROP_2004', 'EXPO_PAMP_2004',
#        'EXPO_PECUAR_2004', 'EXPO_CARNES_2004', 'EXPO_LECHE_2004',
#        'EXPO_LANAS_2004', 'EXPO_CUEROS_PP_2004', 'EXPO_AGRIC_2004',
#        'EXPO_CEREAL_2004', 'EXPO_OLEAGI_2004', 'EXPO_OTAGRIC_2004',
#        'EXPO_PESCA_2004', 'EXPO_INDUST_2004', 'EXPO_ALIMENT_2004',
#        'EXPO_TEXTIL_2004', 'EXPO_CUEROIND_2004', 'EXPO_PAPEL_2004',
#        'EXPO_CAUCHO_2004', 'EXPO_QUIMICO_2004', 'EXPO_COMBIUST_2004',
#        'EXPO_HIERRO_2004', 'EXPO_METNOFERR_2004', 'EXPO_MAQUIN_2004',
#        'EXPO_RESTOIND_2004', 'Consumo.Hogares.ipi.demanda',
#        'Consumo.Gobierno.ipi.demanda',
# ...

# %%
# Ejercicio 14 (b)
# Cambiamos todas las columnas que terminan con vari_Porc a VariPorc

macroFull.columns = [column.replace('vari_Porc', 'VariPorc') for column in macroFull.columns]

# Ejercicio 14 (b)
macroFull.columns = [column.replace('Per_Cap', '_perCap') for column in macroFull.columns]

macroFull.columns
# Out:
# Index(['FBKF.Construcciones.Priv_Publ', 'FBKF.Equi_Dur_Prod.Mat_Transp.Nac',
#        'FBKF.Equi_Dur_Prod.Mat_Transp.Import',
#        'FBKF.Equi_Dur_Prod.Maqui_YEqui.Nac',
#        'FBKF.Equi_Dur_Prod.Maqui_YEqui.Import', 'Consumo.Hogares',
#        'Consumo.Gobierno', 'Exportaciones', 'Importaciones', 'GIB', 'FKBF',
#        'EXPO_TOT_2004', 'EXPO_AGROP_2004', 'EXPO_PAMP_2004',
#        'EXPO_PECUAR_2004', 'EXPO_CARNES_2004', 'EXPO_LECHE_2004',
#        'EXPO_LANAS_2004', 'EXPO_CUEROS_PP_2004', 'EXPO_AGRIC_2004',
#        'EXPO_CEREAL_2004', 'EXPO_OLEAGI_2004', 'EXPO_OTAGRIC_2004',
#        'EXPO_PESCA_2004', 'EXPO_INDUST_2004', 'EXPO_ALIMENT_2004',
#        'EXPO_TEXTIL_2004', 'EXPO_CUEROIND_2004', 'EXPO_PAPEL_2004',
#        'EXPO_CAUCHO_2004', 'EXPO_QUIMICO_2004', 'EXPO_COMBIUST_2004',
#        'EXPO_HIERRO_2004', 'EXPO_METNOFERR_2004', 'EXPO_MAQUIN_2004',
#        'EXPO_RESTOIND_2004', 'Consumo.Hogares.ipi.demanda',
#        'Consumo.Gobierno.ipi.demanda',
# ...

# %% [markdown]
# ### **Ejercicio 15**

# %%
# Ejercicio 15 (a)
# Vemos en qué columnas hay datos faltantes en el dataset macroFull

columnas_con_nulos = macroFull.columns[macroFull.isnull().any()]
columnas_con_nulos
# Out:
# Index(['EXPO_OTAGRIC_2004', 'EXPO_PESCA_2004', 'EXPO_ALIMENT_2004',
#        'EXPO_TEXTIL_2004', 'EXPO_CUEROIND_2004', 'EXPO_PAPEL_2004',
#        'EXPO_CAUCHO_2004', 'EXPO_QUIMICO_2004', 'EXPO_COMBIUST_2004',
#        'EXPO_HIERRO_2004', 'EXPO_METNOFERR_2004', 'EXPO_MAQUIN_2004',
#        'EXPO_RESTOIND_2004', 'PIB_perCap__variPorc',
#        'Vol_Cons_Hogares_per_Cap__VariPorc', 'Vol_FBKF_perCap__variPorc',
#        'IPI__variPorc'],
#       dtype='object')

# %%
# Ejericio 15 (b)
# Vemos en qué años hay datos faltantes en el dataset macroFull

años_con_nulos = macroFull.index[macroFull.isnull().any(axis=1)]
años_con_nulos
# Out:
# Index([1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961,
#        1962, 1963, 1964, 1965],
#       dtype='int64', name='Anio')

# %%
# Ejercicio 15 (c)
# Convertimos todos los datos faltantes en 0 en el dataset macroFull

macroFull = macroFull.fillna(0)
macroFull.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 66 entries, 1950 to 2015
# Data columns (total 83 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   FBKF.Construcciones.Priv_Publ                        66 non-null     int64
#  1   FBKF.Equi_Dur_Prod.Mat_Transp.Nac                    66 non-null     float64
#  2   FBKF.Equi_Dur_Prod.Mat_Transp.Import                 66 non-null     float64
#  3   FBKF.Equi_Dur_Prod.Maqui_YEqui.Nac                   66 non-null     int64
#  4   FBKF.Equi_Dur_Prod.Maqui_YEqui.Import                66 non-null     float64
#  5   Consumo.Hogares                                      66 non-null     float64
#  6   Consumo.Gobierno                                     66 non-null     int64
#  7   Exportaciones                                        66 non-null     float64
# ...

# %% [markdown]
# ### **Ejercicio 16**

# %%
# Cargamos nuevamente el dataset macro_full_columns.csv, usando la columna Anio como índice
macroFull = pd.read_csv('../../Datos/macro_full_columns.csv', index_col='Anio')

# Ejercicio 16 (a)
# Creamos un nuevo dataset que contenga solo las columnas que terminan con "".oferta"

macro_oferta = macroFull.loc[:, macroFull.columns.str.endswith('.oferta')]
macro_oferta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 66 entries, 1950 to 2015
# Data columns (total 11 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Agricultura_caza_silvicultura_y_pesca.oferta   66 non-null     int64
#  1   Explotacion_de_minas_y_canteras.oferta         66 non-null     int64
#  2   Industria_manufacturera.oferta                 66 non-null     float64
#  3   Electricidad_gas_y_agua.oferta                 66 non-null     float64
#  4   Construccion.oferta                            66 non-null     int64
#  5   Comercio_hoteles_y_restaurantes.oferta         66 non-null     float64
#  6   Transp_Almac_y_Comunics.oferta                 66 non-null     int64
#  7   Inter_Fin_Seg_Activ_Inmo_Serv_Empr_etc.oferta  66 non-null     float64
#  8   Servs_Socs_Comunales_Y_Personales.oferta       66 non-null     float64
# ...

# %% [markdown]
# #### Como vemos 👆, no hay datos faltantes en estas columnas

# %%
# Ejercicio 16 (b)
# Creamos un dataframe X que contiene todas las columnas que terminan con ".oferta", excepto la columna "PBI_a_precios_de_mercado.oferta"

X = macroFull.loc[:, macroFull.columns.str.endswith('.oferta') & ~macroFull.columns.str.endswith('PBI_a_precios_de_mercado.oferta')]

# Creamos una Series con los valores de la columna PBI_a_precios_de_mercado.oferta

y = macroFull['PBI_a_precios_de_mercado.oferta']

# %%
# Ejercicio 16 (c)
# Ajustamos un modelo de regresión lineal ordinaria Ridge con X e y

from sklearn.linear_model import Ridge

ridge = Ridge()
ridge.fit(X, y)

# Generamos el vector de predicciones

y_pred = ridge.predict(X)
y_pred
# Out:
# array([1.42404728e+11, 1.47154838e+11, 1.42460680e+11, 1.47218554e+11,
#        1.53087196e+11, 1.63057868e+11, 1.68112710e+11, 1.76874167e+11,
#        1.87676222e+11, 1.76524292e+11, 1.90094309e+11, 2.03089009e+11,
#        1.99456847e+11, 1.96407801e+11, 2.14908549e+11, 2.33202595e+11,
#        2.37092098e+11, 2.44360070e+11, 2.56432456e+11, 2.77398133e+11,
#        2.90263358e+11, 3.01804345e+11, 3.07834528e+11, 3.17329515e+11,
#        3.37281587e+11, 3.33359567e+11, 3.30349397e+11, 3.53732770e+11,
#        3.39911023e+11, 3.64962827e+11, 3.69183394e+11, 3.49122931e+11,
#        3.43070666e+11, 3.58173643e+11, 3.62822586e+11, 3.36765205e+11,
#        3.59825056e+11, 3.71120869e+11, 3.63967879e+11, 3.37176367e+11,
#        3.29271313e+11, 3.60799317e+11, 3.89599897e+11, 4.10542366e+11,
#        4.34358791e+11, 4.22836105e+11, 4.45687211e+11, 4.81321990e+11,
#        4.99429921e+11, 4.81196641e+11, 4.76629357e+11, 4.55825422e+11,
# ...

# %%
# Ejercicio 16 (d)

df_y_y_pred = pd.concat([y, pd.Series(y_pred).set_axis(y.index)], axis=1)
df_y_y_pred

# Graficamos los valores reales de PBI_a_precios_de_mercado.oferta contra los valores predichos

(
    so.Plot(x = df_y_y_pred.index, y = df_y_y_pred["PBI_a_precios_de_mercado.oferta"])
    .add(so.Dot(color="green"))
    .add(so.Dot(color="red"), y = df_y_y_pred[0])
    .label(
        x="Año",
        y="PBI",
        title="PBI a precios de mercado",
    )

)

# %%
df_y_y_pred = pd.concat([y, pd.Series(y_pred).set_axis(y.index)], axis=1)
df_y_y_pred
# Out:
#       PBI_a_precios_de_mercado.oferta             0
# Anio
# 1950                     1.420980e+11  1.424047e+11
# 1951                     1.474360e+11  1.471548e+11
# 1952                     1.404910e+11  1.424607e+11
# 1953                     1.473240e+11  1.472186e+11
# 1954                     1.533160e+11  1.530872e+11
# ...                               ...           ...
# 2011                     7.118760e+11  7.115981e+11
# 2012                     7.064210e+11  7.061319e+11
# 2013                     7.220400e+11  7.219377e+11
# 2014                     7.056120e+11  7.065695e+11
# 2015                     7.225620e+11  7.228990e+11
#
# [66 rows x 2 columns]

# %% [markdown]
# ### **Ejercicio 17**

# %%
# Hallar un escalamiento lineal que transforme los valores de PBI_a_precios_de_mercado.oferta en intervalo [2, 5] al intervalo [0, 1]

from sklearn.preprocessing import MinMaxScaler

#scaler = MinMaxScaler(feature_range=(0, 1))

# Ajustamos el escalamiento

#scaler.fit_transform([y])
