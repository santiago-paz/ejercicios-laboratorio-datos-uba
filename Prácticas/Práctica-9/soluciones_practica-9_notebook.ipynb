# %% [markdown]
# # Práctica 9 - Descenso por gradiente

# %%
from tf_regressor import Regressor , train_test_split_scale_center  # noqa: F401
import pandas as pd
import seaborn.objects as so
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## **Ejercicio 1**

# %% [markdown]
# ### Cargamos el dataset de casos de COVID-19 en Argentina

# %%
df = pd.read_csv("../../Datos/casos_coronavirus.csv")

# %% [markdown]
# ### Ejercicio 1.a)

# %%
df["dias_transcurridos"] = df.index
df.head()
# Out:
#       fecha  confirmados_Nuevos  dias_transcurridos
# 0  3-3-2020                   1                   0
# 1  4-3-2020                   0                   1
# 2  5-3-2020                   1                   2
# 3  6-3-2020                   6                   3
# 4  7-3-2020                   0                   4

# %% [markdown]
# ### Ejercicio 1.b)

# %%
(
    so.Plot(data=df, x="confirmados_Nuevos", y="dias_transcurridos")
    .add(so.Dot())
)

# %% [markdown]
# ### Ejercicio 1.c)

# %% [markdown]
# #### Dividimos el dataset en dos partes: una para entrenamiento y otra para testeo

# %%
X_train, Y_train, X_pred, Y_pred = train_test_split()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 X_train, Y_train, X_pred, Y_pred = pd.train_test_split()
#
# AttributeError: module 'pandas' has no attribute 'train_test_split'
